# %% [markdown]
# # Finance clustering
#
# ## Yahoo Finance
#
# https://finance.yahoo.com/

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.74-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: lxml>=4.5.1 in g:\anaconda\lib\site-packages (from yfinance) (4.8.0)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: numpy>=1.15 in g:\anaconda\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pandas>=0.24.0 in g:\anaconda\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in g:\anaconda\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in g:\anaconda\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in g:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in g:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in g:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in g:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in g:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Installing collected packages: requests, multitasking, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.18.4
#     Uninstalling requests-2.18.4:
#       Successfully uninstalled requests-2.18.4
# Successfully installed multitasking-0.0.11 requests-2.28.1 yfinance-0.1.74
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# google-api-core 1.25.1 requires protobuf>=3.12.0, but you have protobuf 3.11.2 which is incompatible.

# %%
import sys
sys.path.append(
    "../"
)

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import time
from tqdm.autonotebook import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

from tslearn.clustering import TimeSeriesKMeans, silhouette_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from selenium import webdriver
import yfinance as yf

# %%
def get_info(ticker_obj):
    info_keys = ['shortName', 'sector', 'industry', 'country', 'market']
    info_values = []
    for key in info_keys:
        info_values.append(ticker_obj.info.get(key, None))
    return dict(zip(info_keys, info_values))

# %%
msft = yf.Ticker("MSFT")
msft.history()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-12-27  238.699997  238.929993  235.830002  236.960007  16688600
# 2022-12-28  236.889999  239.720001  234.169998  234.529999  17457100
# 2022-12-29  235.649994  241.919998  235.649994  241.009995  19770700
# 2022-12-30  238.210007  239.960007  236.660004  239.820007  21930800
# 2023-01-03  243.080002  245.750000  237.399994  239.580002  25740000
# 2023-01-04  232.279999  232.869995  225.960007  229.100006  50623400
# 2023-01-05  227.199997  227.550003  221.759995  222.309998  39585600
# 2023-01-06  223.000000  225.759995  219.350006  224.929993  43597700
# 2023-01-09  226.449997  231.240005  226.410004  227.119995  27369800
# 2023-01-10  227.759995  231.309998  227.330002  228.850006  27033900
# 2023-01-11  231.289993  235.949997  231.110001  235.770004  28669300
# 2023-01-12  235.259995  239.899994  233.559998  238.509995  27269500
# 2023-01-13  237.000000  239.369995  234.919998  239.229996  21317700
# 2023-01-17  237.970001  240.910004  237.089996  240.350006  29831300
# 2023-01-18  241.570007  242.380005  235.520004  235.809998  30028700
# 2023-01-19  233.779999  235.520004  230.679993  231.929993  28623000
# 2023-01-20  234.860001  240.740005  234.509995  240.220001  35323400
# 2023-01-23  241.100006  245.164993  239.649994  242.580002  30346782
#
#             Dividends  Stock Splits
# Date
# 2022-12-27          0             0
# 2022-12-28          0             0
# 2022-12-29          0             0
# 2022-12-30          0             0
# 2023-01-03          0             0
# 2023-01-04          0             0
# 2023-01-05          0             0
# 2023-01-06          0             0
# 2023-01-09          0             0
# 2023-01-10          0             0
# 2023-01-11          0             0
# 2023-01-12          0             0
# 2023-01-13          0             0
# 2023-01-17          0             0
# 2023-01-18          0             0
# 2023-01-19          0             0
# 2023-01-20          0             0
# 2023-01-23          0             0

# %%
get_info(msft)
# Out:
# {'shortName': None,
#  'sector': None,
#  'industry': None,
#  'country': None,
#  'market': None}

# %% [markdown]
# ## In case you need all tickers

# %%
all_tickers = pd.read_csv(
    'https://raw.githubusercontent.com/shilewenuw/get_all_tickers/master/get_all_tickers/tickers.csv', 
    header=None,
    error_bad_lines=False
)

all_tickers = all_tickers.values.reshape(-1)
print(len(all_tickers))
print(all_tickers[:4]) # ['DDD' 'MMM' 'WBAI' 'WUBA']
# Out:
# 2762
# ['DDD' 'MMM' 'WBAI' 'WUBA']

# %% [markdown]
# ## Loading interesting tickers

# %%
from selenium.webdriver.common.by import By

def load_with_selenium(url, chromedriver_path='C:/Windows/chromedriver.exe'): # https://chromedriver.chromium.org/downloads
    driver = webdriver.Chrome(chromedriver_path)
    driver.get(url)
    driver.implicitly_wait(2)
    df = pd.read_html(driver.find_element(By.TAG_NAME, "table").get_attribute('outerHTML'))[0]
    driver.close()
    return df

# %%
# %%time
n_group = 25

trending = load_with_selenium(f"https://finance.yahoo.com/trending-tickers?count={n_group}")
most_active = load_with_selenium(f"https://finance.yahoo.com/most-active?count={n_group}")
gainers = load_with_selenium(f"https://finance.yahoo.com/gainers?count={n_group}")
losers = load_with_selenium(f"https://finance.yahoo.com/losers?count={n_group}")
# Out:
# CPU times: total: 93.8 ms
# Wall time: 44.7 s

# %%
trending.head()
# Out:
#   Symbol                            Name  Last Price Market Time  Change  \
# 0   TSLA                     Tesla, Inc.      143.75  4:00PM EST   10.33
# 1    AMD    Advanced Micro Devices, Inc.       76.53  4:00PM EST    6.46
# 2    NIO                        NIO Inc.       12.06  4:03PM EST    0.99
# 3   INBS  Intelligent Bio Solutions Inc.        1.03  4:00PM EST    0.76
# 4    GME                  GameStop Corp.       21.66  4:00PM EST    2.05
#
#    % Change    Volume Market Cap  Intraday High/Low  52 Week Range  Day Chart
# 0    +7.74%  199.849M   453.927B                NaN            NaN        NaN
# 1    +9.22%   83.356M   123.394B                NaN            NaN        NaN
# 2    +8.94%   63.614M    20.147B                NaN            NaN        NaN
# 3  +281.48%  145.707M    18.904M                NaN            NaN        NaN
# 4   +10.45%    7.132M     6.597B                NaN            NaN        NaN

# %%
most_active.head()
# Out:
#   Symbol                          Name  Price (Intraday)  Change % Change  \
# 0   TSLA                   Tesla, Inc.            143.75   10.33   +7.74%
# 1    AMD  Advanced Micro Devices, Inc.             76.53    6.46   +9.22%
# 2   AAPL                    Apple Inc.            141.11    3.24   +2.35%
# 3   AMZN              Amazon.com, Inc.             97.52    0.27   +0.28%
# 4    NIO                      NIO Inc.             12.06    0.99   +8.94%
#
#      Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0  199.849M          125.839M   453.927B           42.40            NaN
# 1   83.356M           65.032M   123.394B           45.28            NaN
# 2   79.729M           81.738M     2.235T           23.09            NaN
# 3    74.89M           85.208M    994.87B           85.54            NaN
# 4   63.614M           59.484M    20.147B             NaN            NaN

# %%
gainers.head()
# Out:
#   Symbol                                         Name  Price (Intraday)  \
# 0  CMGGF  Commercial International Bank (Egypt) S.A.E             1.567
# 1      W                                 Wayfair Inc.            59.330
# 2  PHJMF             PT Hanjaya Mandala Sampoerna Tbk             0.063
# 3   AQUA              Evoqua Water Technologies Corp.            47.280
# 4   LCID                            Lucid Group, Inc.             8.820
#
#     Change % Change   Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  \
# 0   0.3970  +33.93%    64200             10755     6.145B            9.79
# 1  12.5400  +26.80%  27.261M            4.731M     6.356B             NaN
# 2   0.0126  +25.00%   121564            425959     7.917B             NaN
# 3   6.2500  +15.23%  17.801M            599847     5.763B           80.14
# 4   1.0000  +12.79%  37.655M           26.818M    16.126B            8.65
#
#    52 Week Range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
losers.head()
# Out:
#   Symbol                   Name  Price (Intraday)  Change % Change   Volume  \
# 0  CHFLF    China Feihe Limited              0.83  -0.155  -15.74%   331145
# 1    XYL             Xylem Inc.            101.42  -8.760   -7.95%  11.499M
# 2   MGPI  MGP Ingredients, Inc.             96.52  -5.700   -5.58%   402426
# 3   TRMD               TORM plc             26.08  -1.540   -5.58%   343354
# 4  DIDIY       DiDi Global Inc.              4.60  -0.230   -4.76%  12.156M
#
#   Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0            949084     7.748B            9.22            NaN
# 1            866691    18.278B           57.62            NaN
# 2            110934     2.123B           18.07            NaN
# 3            265908     2.134B            6.47            NaN
# 4           14.494M    22.329B             NaN            NaN

# %%
# Исключим пересечения. Возьмем только уникальные тикеты
interesting_tickers = set()

for df in [trending, most_active, gainers, losers]:
    interesting_tickers = interesting_tickers.union(set(df['Symbol']))
    
interesting_tickers = list(interesting_tickers)
print(interesting_tickers[:4])
print(len(interesting_tickers))
# Out:
# ['AQUA', 'COMP', 'GOOGL', 'RIVN']
# 87

# %%
# True about 15-20 min 
# False - use prepared data from full_ticker_df_month.csv

load = False 

if load:
    full_ticker_data = []
    for ticker in tqdm(interesting_tickers):
        try:
            ticker_obj = yf.Ticker(ticker)
            close_price = ticker_obj.history(period='1mo', interval='1d')['Close'].to_dict()
            info = get_info(ticker_obj)
            info.update(close_price)
            full_ticker_data.append(info)
        except Exception as e:
            print(e)
            continue
        
    full_ticker_df = pd.DataFrame(full_ticker_data)
    full_ticker_df.to_csv("full_ticker_df_month.csv")

else: 
    full_ticker_df = pd.read_csv("full_ticker_df_month.csv", index_col=0)
    datetime_columns = pd.to_datetime(full_ticker_df.columns[5:])
    full_ticker_df.columns = list(full_ticker_df.columns[:5]) + list(datetime_columns)

# %%
full_ticker_df.head()
# Out:
#                          shortName                  sector  \
# 0                 Farfetch Limited       Consumer Cyclical
# 1                        Snap Inc.  Communication Services
# 2                    Arvinas, Inc.              Healthcare
# 3  COLOPLAST SPON ADS EACH REPR 0.              Healthcare
# 4                      Carvana Co.       Consumer Cyclical
#
#                          industry         country     market  \
# 0                 Internet Retail  United Kingdom  us_market
# 1  Internet Content & Information   United States  us_market
# 2                   Biotechnology   United States  us_market
# 3  Medical Instruments & Supplies         Denmark  us_market
# 4                 Internet Retail   United States  us_market
#
#    2022-07-18 00:00:00  2022-07-19 00:00:00  2022-07-20 00:00:00  \
# 0                 6.73             7.760000             8.350000
# 1                13.92            14.150000            15.510000
# 2                47.50            51.919998            54.560001
# 3                11.19            11.425000            11.205000
# 4                22.25            22.850000            27.379999
#
#    2022-07-21 00:00:00  2022-07-22 00:00:00  ...  2022-08-05 00:00:00  \
# 0             8.820000             8.360000  ...                 8.94
# 1            16.350000             9.960000  ...                10.18
# 2            54.799999            50.320000  ...                55.43
# 3            11.810000            11.850000  ...                11.34
# 4            28.209999            25.379999  ...                46.98
#
#    2022-08-08 00:00:00  2022-08-09 00:00:00  2022-08-10 00:00:00  \
# 0             9.720000             8.880000             9.710000
# 1            10.410000            10.160000            10.570000
# 2            55.830002            55.799999            57.990002
# 3            11.410000            11.380000            11.730000
# 4            46.459999            41.430000            47.310001
#
#    2022-08-11 00:00:00  2022-08-12 00:00:00  2022-08-15 00:00:00  \
# 0             9.900000            10.160000             9.930000
# 1            11.110000            11.620000            12.240000
# 2            54.540001            54.459999            54.119999
# 3            11.820000            11.600000            11.585000
# 4            50.130001            52.099998            51.000000
#
#    2022-08-16 00:00:00  2022-08-17 00:00:00  2022-08-18 00:00:00
# 0                 9.99             8.830000                  NaN
# 1                12.61            12.090000                  NaN
# 2                52.48            46.700001                  NaN
# 3                11.34            12.170000                  NaN
# 4                54.59            49.619999                  NaN
#
# [5 rows x 29 columns]

# %%
full_ticker_df.shape
# Out:
# (96, 29)

# %%
full_ticker_df.isnull().sum(axis=1)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 91    1
# 92    1
# 93    1
# 94    1
# 95    1
# Length: 96, dtype: int64

# %%
full_ticker_df = full_ticker_df.iloc[:, :-1] # Выбросим пустой столбец

# %%
prices = full_ticker_df.iloc[:, 5:].T

# %%
prices
# Out:
#                         0      1          2       3          4           5   \
# 2022-07-18 00:00:00   6.73  13.92  47.500000  11.190  22.250000  211.000000
# 2022-07-19 00:00:00   7.76  14.15  51.919998  11.425  22.850000  214.470001
# 2022-07-20 00:00:00   8.35  15.51  54.560001  11.205  27.379999  216.809998
# 2022-07-21 00:00:00   8.82  16.35  54.799999  11.810  28.209999  213.279999
# 2022-07-22 00:00:00   8.36   9.96  50.320000  11.850  25.379999  209.800003
# 2022-07-25 00:00:00   8.08   9.95  49.790001  11.600  25.200001  221.570007
# 2022-07-26 00:00:00   7.43   9.63  51.400002  11.580  24.180000  218.580002
# 2022-07-27 00:00:00   8.16   9.55  53.029999  11.635  26.360001  226.539993
# 2022-07-28 00:00:00   7.96   9.67  52.869999  11.590  27.180000  228.669998
# 2022-07-29 00:00:00   7.94   9.88  53.110001  11.710  29.150000  236.949997
# 2022-08-01 00:00:00   8.23   9.54  50.380001  11.715  30.170000  228.100006
# 2022-08-02 00:00:00   8.41   9.87  51.369999  11.630  34.049999  227.910004
# 2022-08-03 00:00:00   9.27  10.32  53.410000  11.600  34.900002  220.679993
# 2022-08-04 00:00:00   9.03  10.25  51.410000  11.900  33.540001  212.860001
# 2022-08-05 00:00:00   8.94  10.18  55.430000  11.340  46.980000  217.149994
# 2022-08-08 00:00:00   9.72  10.41  55.830002  11.410  46.459999  217.139999
# 2022-08-09 00:00:00   8.88  10.16  55.799999  11.380  41.430000  218.190002
# 2022-08-10 00:00:00   9.71  10.57  57.990002  11.730  47.310001  217.800003
# 2022-08-11 00:00:00   9.90  11.11  54.540001  11.820  50.130001  228.479996
# 2022-08-12 00:00:00  10.16  11.62  54.459999  11.600  52.099998  232.949997
# 2022-08-15 00:00:00   9.93  12.24  54.119999  11.585  51.000000  229.940002
# 2022-08-16 00:00:00   9.99  12.61  52.480000  11.340  54.590000  229.119995
# 2022-08-17 00:00:00   8.83  12.09  46.700001  12.170  49.619999  232.500000
#
#                             6           7          8       9   ...    86  \
# 2022-07-18 00:00:00  26.100000   93.139999  26.240000  0.1754  ...  6.06
# 2022-07-19 00:00:00  28.290001   98.230003  26.530001  0.1754  ...  6.41
# 2022-07-20 00:00:00  28.680000  102.230003  25.600000  0.1754  ...  6.76
# 2022-07-21 00:00:00  28.450001  103.839996  25.740000  0.1754  ...  6.67
# 2022-07-22 00:00:00  26.030001  101.669998  25.600000  0.1754  ...  6.55
# 2022-07-25 00:00:00  24.600000  101.000000  25.719999  0.1754  ...  7.19
# 2022-07-26 00:00:00  22.660000   98.910004  25.610001  0.1754  ...  7.28
# 2022-07-27 00:00:00  24.770000  103.459999  25.879999  0.1754  ...  7.33
# 2022-07-28 00:00:00  24.370001  105.160004  25.590000  0.1754  ...  6.97
# 2022-07-29 00:00:00  24.330000  105.980003  25.920000  0.1754  ...  7.06
# 2022-08-01 00:00:00  23.940001  106.400002  26.170000  0.1754  ...  6.92
# 2022-08-02 00:00:00  25.440001  104.989998  26.240000  0.1471  ...  6.77
# 2022-08-03 00:00:00  29.059999  109.010002  26.150000  0.1561  ...  6.68
# 2022-08-04 00:00:00  28.330000  111.059998  25.910000  0.1561  ...  6.49
# 2022-08-05 00:00:00  29.600000  109.620003  25.240000  0.1561  ...  6.83
# 2022-08-08 00:00:00  32.270000  107.830002  25.570000  0.1561  ...  6.54
# 2022-08-09 00:00:00  28.450001   99.660004  25.770000  0.1561  ...  6.77
# 2022-08-10 00:00:00  33.500000  105.050003  26.389999  0.1500  ...  6.93
# 2022-08-11 00:00:00  31.709999  105.529999  26.639999  0.1500  ...  7.49
# 2022-08-12 00:00:00  34.759998  110.379997  26.500000  0.1500  ...  7.51
# 2022-08-15 00:00:00  33.080002  109.779999  26.410000  0.1500  ...  7.24
# 2022-08-16 00:00:00  36.279999  108.489998  26.250000  0.1500  ...  7.50
# 2022-08-17 00:00:00  33.009998  106.000000  27.309999  0.1610  ...  7.41
#
#                         87          88        89    90         91        92  \
# 2022-07-18 00:00:00  4.410  245.770004  0.708124  0.97  52.459999  2.839500
# 2022-07-19 00:00:00  4.410  255.399994  0.698289  0.95  55.520000  2.918375
# 2022-07-20 00:00:00  4.410  257.799988  0.688454  1.06  55.150002  2.967672
# 2022-07-21 00:00:00  4.410  262.570007  0.698289  1.06  55.240002  3.036687
# 2022-07-22 00:00:00  4.410  260.100006  0.658948  1.02  51.880001  3.026828
# 2022-07-25 00:00:00  4.410  258.690002  0.698289  1.05  51.040001  3.066265
# 2022-07-26 00:00:00  4.410  251.820007  0.708124  1.04  50.669998  3.066265
# 2022-07-27 00:00:00  4.410  263.420013  0.757299  1.05  51.709999  3.155000
# 2022-07-28 00:00:00  4.410  271.290009  0.757299  1.05  51.970001  3.250000
# 2022-07-29 00:00:00  4.410  273.100006  0.786804  1.01  51.060001  3.220000
# 2022-08-01 00:00:00  4.410  273.510010  0.727794  0.98  50.599998  3.260000
# 2022-08-02 00:00:00  4.410  268.390015  0.776969  1.06  56.290001  3.210000
# 2022-08-03 00:00:00  4.410  269.559998  0.806474  1.02  59.700001  3.220000
# 2022-08-04 00:00:00  4.410  273.309998  0.875320  1.02  64.720001  3.170000
# 2022-08-05 00:00:00  4.410  270.739990  0.894990  0.90  68.139999  3.160000
# 2022-08-08 00:00:00  4.410  270.160004  0.924495  1.04  71.089996  3.170000
# 2022-08-09 00:00:00  4.410  265.630005  0.914660  1.00  68.169998  3.160000
# 2022-08-10 00:00:00  4.410  272.500000  0.973670  1.05  70.980003  3.210000
# 2022-08-11 00:00:00  4.410  270.359985  0.954000  1.05  69.720001  3.260000
# 2022-08-12 00:00:00  4.410  275.380005  0.990000  1.07  72.220001  3.280000
# 2022-08-15 00:00:00  4.410  276.369995  0.940000  1.05  69.949997  3.260000
# 2022-08-16 00:00:00  4.410  276.109985  0.900000  1.10  68.550003  3.250000
# 2022-08-17 00:00:00  5.145  276.519989  1.010000  1.21  61.169998  3.210000
#
#                        93     94    95
# 2022-07-18 00:00:00  2.51  5.030  0.78
# 2022-07-19 00:00:00  2.62  5.530  0.79
# 2022-07-20 00:00:00  2.55  5.660  0.79
# 2022-07-21 00:00:00  2.55  5.610  0.84
# 2022-07-22 00:00:00  2.55  5.170  0.84
# 2022-07-25 00:00:00  2.63  4.940  0.84
# 2022-07-26 00:00:00  2.68  4.650  0.82
# 2022-07-27 00:00:00  2.70  4.750  0.82
# 2022-07-28 00:00:00  2.73  5.040  0.79
# 2022-07-29 00:00:00  2.75  4.910  0.79
# 2022-08-01 00:00:00  2.74  4.790  0.82
# 2022-08-02 00:00:00  2.73  4.850  0.77
# 2022-08-03 00:00:00  2.78  5.210  0.80
# 2022-08-04 00:00:00  2.87  4.700  0.82
# 2022-08-05 00:00:00  2.95  5.720  0.84
# 2022-08-08 00:00:00  2.97  5.890  0.84
# 2022-08-09 00:00:00  3.00  5.430  0.87
# 2022-08-10 00:00:00  3.05  5.940  0.85
# 2022-08-11 00:00:00  3.05  5.990  0.93
# 2022-08-12 00:00:00  3.13  6.300  0.92
# 2022-08-15 00:00:00  3.10  6.010  0.97
# 2022-08-16 00:00:00  3.12  5.680  1.01
# 2022-08-17 00:00:00  3.25  5.085  1.08
#
# [23 rows x 96 columns]

# %%
prices = prices.fillna(method='backfill')  #Заполним пропуски назад
prices = prices.fillna(method='ffill')     #Заполним пропуски вперед

# %%
full_ticker_df = full_ticker_df.iloc[:, :5].join(prices.T) #Выкинуть пропуски

# %%
full_ticker_df.dropna(inplace=True)

# %%
full_ticker_df.shape
# Out:
# (96, 28)

# %% [markdown]
# # Время провернуть кластерный анализ по финансовом рынке

# %%
full_ticker_df.sample(15)
# Out:
#                           shortName              sector  \
# 13  ADYEN NV UNSPON ADS EACH REP 0.          Technology
# 75       Highwoods Properties, Inc.         Real Estate
# 34               NVIDIA Corporation          Technology
# 40   COSCO SHIPPING ENGY TPT CO LTD         Industrials
# 31                         NICE Ltd          Technology
# 37              Canadian Solar Inc.          Technology
# 17         Codiak BioSciences, Inc.          Healthcare
# 60          DONGFENG MOTOR GROUP CO   Consumer Cyclical
# 27  BJ's Wholesale Club Holdings, I  Consumer Defensive
# 76                 Amazon.com, Inc.   Consumer Cyclical
# 93                Banco Bradesco Sa  Financial Services
# 83                       Apple Inc.          Technology
# 63       Agilent Technologies, Inc.          Healthcare
# 74                      WeWork Inc.         Real Estate
# 36                Cano Health, Inc.          Healthcare
#
#                    industry        country     market  2022-07-18 00:00:00  \
# 13  Software—Infrastructure    Netherlands  us_market            15.670000
# 75              REIT—Office  United States  us_market            33.740002
# 34           Semiconductors  United States  us_market           161.009995
# 40          Marine Shipping          China  us_market             0.645000
# 31     Software—Application         Israel  us_market           198.850006
# 37                    Solar         Canada  us_market            30.160000
# 17            Biotechnology  United States  us_market             2.780000
# 60       Auto Manufacturers          China  us_market             0.780000
# 27          Discount Stores  United States  us_market            69.290001
# 76          Internet Retail  United States  us_market           113.760002
# 93           Banks—Regional         Brazil  us_market             2.510000
# 83     Consumer Electronics  United States  us_market           146.865997
# 63   Diagnostics & Research  United States  us_market           115.110001
# 74     Real Estate Services  United States  us_market             5.200000
# 36  Medical Care Facilities  United States  us_market             5.550000
#
#     2022-07-19 00:00:00  2022-07-20 00:00:00  2022-07-21 00:00:00  \
# 13            16.270000            16.330000            17.070000
# 75            34.619999            34.439999            34.240002
# 34           169.919998           178.070007           180.500000
# 40             0.645000             0.645000             0.645000
# 31           203.100006           211.500000           212.839996
# 37            30.760000            31.940001            31.480000
# 17             2.660000             2.650000             2.700000
# 60             0.780000             0.780000             0.780000
# 27            68.949997            69.769997            69.139999
# 76           118.209999           122.769997           124.629997
# 93             2.620000             2.550000             2.550000
# 83           150.790543           152.827713           155.134521
# 63           119.059998           119.860001           127.190002
# 74             5.260000             5.410000             5.220000
# 36             5.860000             5.710000             6.500000
#
#     2022-07-22 00:00:00  ...  2022-08-04 00:00:00  2022-08-05 00:00:00  \
# 13            16.559999  ...            18.690001            17.959999
# 75            34.630001  ...            33.139999            33.180000
# 34           173.190002  ...           192.149994           189.889999
# 40             0.645000  ...             0.750000             0.750000
# 31           208.669998  ...           221.339996           221.059998
# 37            32.200001  ...            37.320000            38.669998
# 17             2.570000  ...             2.550000             2.390000
# 60             0.780000  ...             0.740000             0.740000
# 27            69.459999  ...            69.360001            70.500000
# 76           122.419998  ...           142.570007           140.800003
# 93             2.550000  ...             2.870000             2.950000
# 83           153.876251  ...           165.580002           165.350006
# 63           125.040001  ...           133.770004           133.610001
# 74             5.090000  ...             4.730000             4.690000
# 36             6.530000  ...             6.110000             6.140000
#
#     2022-08-08 00:00:00  2022-08-09 00:00:00  2022-08-10 00:00:00  \
# 13            18.559999            18.240000            19.100000
# 75            33.630001            33.549999            34.480000
# 34           177.929993           170.860001           180.970001
# 40             0.750000             0.750000             0.750000
# 31           223.940002           218.750000           228.729996
# 37            39.119999            39.849998            41.919998
# 17             2.450000             2.290000             2.390000
# 60             0.740000             0.740000             0.740000
# 27            70.980003            70.510002            70.809998
# 76           139.410004           137.830002           142.690002
# 93             2.970000             3.000000             3.050000
# 83           164.869995           164.919998           169.240005
# 63           132.520004           128.880005           132.580002
# 74             5.070000             4.650000             5.110000
# 36             6.060000             5.460000             4.740000
#
#     2022-08-11 00:00:00  2022-08-12 00:00:00  2022-08-15 00:00:00  \
# 13            19.080000            19.200001            18.940001
# 75            35.349998            35.459999            35.060001
# 34           179.419998           187.089996           190.320007
# 40             0.750000             0.750000             0.710000
# 31           223.990005           231.210007           232.059998
# 37            40.950001            41.900002            41.400002
# 17             2.290000             2.390000             2.460000
# 60             0.740000             0.740000             0.740000
# 27            69.559998            68.290001            69.110001
# 76           140.639999           143.550003           143.179993
# 93             3.050000             3.130000             3.100000
# 83           168.490005           172.100006           173.190002
# 63           131.949997           133.550003           133.899994
# 74             5.580000             5.740000             5.470000
# 36             4.930000             5.120000             4.800000
#
#     2022-08-16 00:00:00  2022-08-17 00:00:00
# 13            18.360001            18.510000
# 75            35.209999            34.529999
# 34           188.789993           183.350006
# 40             0.764000             0.830000
# 31           226.039993           228.539993
# 37            39.930000            39.230000
# 17             2.300000             2.310000
# 60             0.740000             0.650000
# 27            69.239998            69.129997
# 76           144.779999           142.100006
# 93             3.120000             3.250000
# 83           173.029999           174.550003
# 63           132.770004           142.289993
# 74             5.760000             5.250000
# 36             4.690000             5.210000
#
# [15 rows x 28 columns]

# %% [markdown]
# ## Scaling everything

# %%
scaler = StandardScaler()
tickers_scaled = scaler.fit_transform(full_ticker_df.iloc[:, 5:-1].T).T # -1 - последний час есть данные не по всем бумагам

# %%
plt.figure(figsize=(10, 10))
plt.plot(tickers_scaled.T);

# %% [markdown]
# # Basic KMeans

# %%
distortions = [] # Сумма кв расстояний от объектов до центра кластера, взвешенная по весам (при их наличии)
silhouette = []
K = range(2, 10)
for k in tqdm(K):
    kmeanModel = TimeSeriesKMeans(n_clusters=k, metric="euclidean", n_jobs=6, max_iter=10, n_init=5)
    kmeanModel.fit(tickers_scaled)
    distortions.append(kmeanModel.inertia_)
    silhouette.append(silhouette_score(tickers_scaled, kmeanModel.labels_, metric="euclidean"))
    # silhouette_score считает насколько чисты кластеры
    
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(K, distortions, 'b-')
ax2.plot(K, silhouette, 'r-')

ax1.set_xlabel('# clusters')
ax1.set_ylabel('Distortion', color='b')
ax2.set_ylabel('Silhouette', color='r')

plt.show()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
n_clusters = 4
ts_kmeans = TimeSeriesKMeans(n_clusters=n_clusters, metric="euclidean", n_jobs=6, max_iter=10)
ts_kmeans.fit(tickers_scaled)
# Out:
# TimeSeriesKMeans(max_iter=10, n_clusters=4, n_jobs=6)

# %%
for cluster_number in range(n_clusters): # Построим усредненные ряды внутри каждого кластера
    plt.plot(ts_kmeans.cluster_centers_[cluster_number, :, 0].T, label=cluster_number)
plt.title("Cluster centroids") # Быки и медведи
plt.legend()
plt.show()

# %%
# посмотрим наличие корреляции между полученными кластерами и биржевыми секторами
full_ticker_df['cluster'] = ts_kmeans.predict(tickers_scaled)
pd.DataFrame(full_ticker_df.groupby('cluster')['sector'].value_counts())
# Out:
#                                 sector
# cluster sector
# 0       Healthcare                   8
#         Consumer Cyclical            3
#         Financial Services           3
#         Consumer Defensive           2
#         Industrials                  2
#         Real Estate                  2
#         Technology                   2
#         Communication Services       1
# 1       Healthcare                   6
#         Communication Services       3
#         Industrials                  2
#         Consumer Cyclical            1
#         Consumer Defensive           1
#         Energy                       1
#         Financial Services           1
#         Real Estate                  1
#         Technology                   1
# 2       Technology                   9
#         Healthcare                   5
#         Consumer Cyclical            3
#         Consumer Defensive           1
#         Energy                       1
#         Financial Services           1
#         Industrials                  1
#         Real Estate                  1
# 3       Energy                       6
#         Financial Services           6
#         Technology                   6
#         Industrials                  4
#         Consumer Cyclical            3
#         Basic Materials              2
#         Communication Services       2
#         Consumer Defensive           2
#         Healthcare                   1
#         Real Estate                  1
#         Utilities                    1

# %%
def plot_cluster_tickers(current_cluster):
    fig, ax = plt.subplots(
        int(np.ceil(current_cluster.shape[0]/4)),
        4,
        figsize=(15, 3*int(np.ceil(current_cluster.shape[0]/4)))
    )
    fig.autofmt_xdate(rotation=45)
    ax = ax.reshape(-1)

    for index, (_, row) in enumerate(current_cluster.iterrows()):
        ax[index].plot(row.iloc[5:-1])
        ax[index].set_title(f"{row.shortName}\n{row.sector}")
        plt.xticks(rotation=45)

    plt.tight_layout()
    plt.show()

# %%
# TimeSeriesKMeans
for cluster in range(n_clusters):
    print("=================================================================================")
    print(f"                          Cluster number: {cluster}")
    print("=================================================================================")
    plot_cluster_tickers(full_ticker_df[full_ticker_df.cluster==cluster])
# Out:
# =================================================================================
#                           Cluster number: 0
# =================================================================================
# =================================================================================
#                           Cluster number: 1
# =================================================================================
# =================================================================================
#                           Cluster number: 2
# =================================================================================
# =================================================================================
#                           Cluster number: 3
# =================================================================================

# %% [markdown]
# # DTW

# %%
from tslearn.clustering import TimeSeriesKMeans, silhouette_score
distortions = []
silhouette = []
K = range(2, 10)
for k in tqdm(K):
    kmeanModel = TimeSeriesKMeans(n_clusters=k, metric="dtw", n_jobs=6, max_iter=10, n_init=5)
    kmeanModel.fit(tickers_scaled)
    distortions.append(kmeanModel.inertia_)
    silhouette.append(silhouette_score(tickers_scaled, kmeanModel.labels_, metric="dtw"))
    
    # silhouette_score считает насколько чисты класстеры
    # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html
    # Для metric="dtw" берем реализацию из tslearn:
    # https://tslearn.readthedocs.io/en/stable/gen_modules/clustering/tslearn.clustering.silhouette_score.html

    
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(K, distortions, 'b-')
ax2.plot(K, silhouette, 'r-')

ax1.set_xlabel('# clusters')
ax1.set_ylabel('Distortion', color='b')
ax2.set_ylabel('Silhouette', color='r')

plt.show()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
n_clusters = 4
ts_kmeans_dtw = TimeSeriesKMeans(n_clusters=n_clusters, metric="dtw", n_jobs=6, max_iter=10,random_state=42)
ts_kmeans_dtw.fit(tickers_scaled)

for cluster_number in range(n_clusters):
    plt.plot(ts_kmeans_dtw.cluster_centers_[cluster_number, :, 0].T, label=cluster_number)
plt.title("Cluster centroids")
plt.legend()
plt.show()

# %%
full_ticker_df['cluster'].value_counts()
# Out:
# 3    34
# 0    23
# 2    22
# 1    17
# Name: cluster, dtype: int64

# %%
full_ticker_df['cluster'] = ts_kmeans_dtw.predict(tickers_scaled)
pd.DataFrame(full_ticker_df.groupby('cluster')['sector'].value_counts())
# Out:
#                                 sector
# cluster sector
# 0       Technology                  14
#         Healthcare                   7
#         Consumer Cyclical            5
#         Financial Services           5
#         Energy                       3
#         Industrials                  3
#         Consumer Defensive           2
#         Basic Materials              1
#         Real Estate                  1
#         Utilities                    1
# 1       Healthcare                   4
#         Industrials                  2
#         Communication Services       1
#         Consumer Cyclical            1
#         Consumer Defensive           1
#         Energy                       1
#         Financial Services           1
#         Technology                   1
# 2       Healthcare                   4
#         Consumer Defensive           3
#         Real Estate                  3
#         Communication Services       2
#         Consumer Cyclical            1
#         Energy                       1
#         Technology                   1
# 3       Financial Services           5
#         Healthcare                   5
#         Industrials                  4
#         Communication Services       3
#         Consumer Cyclical            3
#         Energy                       3
#         Technology                   2
#         Basic Materials              1
#         Real Estate                  1

# %%
for cluster in range(n_clusters):
    print("=================================================================================")
    print(f"                          Cluster number: {cluster}")
    print("=================================================================================")
    plot_cluster_tickers(full_ticker_df[full_ticker_df.cluster==cluster])
# Out:
# =================================================================================
#                           Cluster number: 0
# =================================================================================
# =================================================================================
#                           Cluster number: 1
# =================================================================================
# =================================================================================
#                           Cluster number: 2
# =================================================================================
# =================================================================================
#                           Cluster number: 3
# =================================================================================
